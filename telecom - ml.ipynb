# %%
import numpy as np
import pandas as pd
import plotly.express as px

# %%
#to view all cols of the df
pd.set_option('display.max_columns', None)

# %%
#read the data
df = pd.read_csv('churn_data.csv')

# %%
df.head(20)
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents     MultipleLines  \
# 0   7590-VHVEG  Female              0     Yes         No  No phone service
# 1   5575-GNVDE    Male              0      No         No                No
# 2   3668-QPYBK    Male              0      No         No                No
# 3   7795-CFOCW    Male              0      No         No  No phone service
# 4   9237-HQITU  Female              0      No         No                No
# 5   9305-CDSKC  Female              0      No         No               Yes
# 6   1452-KIOVK    Male              0      No        Yes               Yes
# 7   6713-OKOMC  Female              0      No         No  No phone service
# 8   7892-POOKP  Female              0     Yes         No               Yes
# 9   6388-TABGU    Male              0      No        Yes                No
# 10  9763-GRSKD    Male              0     Yes        Yes                No
# 11  7469-LKBCI    Male              0      No         No                No
# 12  8091-TTVAX    Male              0     Yes         No               Yes
# 13  0280-XJGEX    Male              0      No         No               Yes
# 14  5129-JLPIS    Male              0      No         No                No
# 15  3655-SNQYZ  Female              0     Yes        Yes               Yes
# 16  8191-XWSZG  Female              0      No         No                No
# 17  9959-WOFKT    Male              0      No        Yes               Yes
# 18  4190-MFLUW  Female              0     Yes        Yes                No
# 19  4183-MYFRB  Female              0      No         No                No
#
#    InternetService       OnlineSecurity         OnlineBackup  \
# 0              DSL                   No                  Yes
# 1              DSL                  Yes                   No
# 2              DSL                  Yes                  Yes
# 3              DSL                  Yes                   No
# 4      Fiber optic                   No                   No
# 5      Fiber optic                   No                   No
# 6      Fiber optic                   No                  Yes
# 7              DSL                  Yes                   No
# 8      Fiber optic                   No                   No
# 9              DSL                  Yes                  Yes
# 10             DSL                  Yes                   No
# 11              No  No internet service  No internet service
# 12     Fiber optic                   No                   No
# 13     Fiber optic                   No                  Yes
# 14     Fiber optic                  Yes                   No
# 15     Fiber optic                  Yes                  Yes
# 16              No  No internet service  No internet service
# 17     Fiber optic                  Yes                   No
# 18             DSL                   No                   No
# 19     Fiber optic                   No                  Yes
#
#        DeviceProtection          TechSupport          StreamingTV  \
# 0                    No                   No                   No
# 1                   Yes                   No                   No
# 2                    No                   No                   No
# 3                   Yes                  Yes                   No
# 4                    No                   No                   No
# 5                   Yes                   No                  Yes
# 6                    No                   No                  Yes
# 7                    No                   No                   No
# 8                   Yes                  Yes                  Yes
# 9                    No                   No                   No
# 10                   No                   No                   No
# 11  No internet service  No internet service  No internet service
# 12                  Yes                   No                  Yes
# 13                  Yes                   No                  Yes
# 14                  Yes                  Yes                  Yes
# 15                  Yes                  Yes                  Yes
# 16  No internet service  No internet service  No internet service
# 17                  Yes                   No                  Yes
# 18                  Yes                  Yes                   No
# 19                  Yes                   No                   No
#
#         StreamingMovies  Unnamed: 13  tenure PhoneService        Contract  \
# 0                    No          NaN       1           No  Month-to-month
# 1                    No          NaN      34          Yes        One year
# 2                    No          NaN       2          Yes  Month-to-month
# 3                    No          NaN      45           No        One year
# 4                    No          NaN       2          Yes  Month-to-month
# 5                   Yes          NaN       8          Yes  Month-to-month
# 6                    No          NaN      22          Yes  Month-to-month
# 7                    No          NaN      10           No  Month-to-month
# 8                   Yes          NaN      28          Yes  Month-to-month
# 9                    No          NaN      62          Yes        One year
# 10                   No          NaN      13          Yes  Month-to-month
# 11  No internet service          NaN      16          Yes        Two year
# 12                  Yes          NaN      58          Yes        One year
# 13                  Yes          NaN      49          Yes  Month-to-month
# 14                  Yes          NaN      25          Yes  Month-to-month
# 15                  Yes          NaN      69          Yes        Two year
# 16  No internet service          NaN      52          Yes        One year
# 17                  Yes          NaN      71          Yes        Two year
# 18                   No          NaN      10          Yes  Month-to-month
# 19                  Yes          NaN      21          Yes  Month-to-month
#
#    PaperlessBilling              PaymentMethod  MonthlyCharges TotalCharges  \
# 0               Yes           Electronic check           29.85        29.85
# 1                No               Mailed check           56.95       1889.5
# 2               Yes               Mailed check           53.85       108.15
# 3                No  Bank transfer (automatic)           42.30      1840.75
# 4               Yes           Electronic check           70.70       151.65
# 5               Yes           Electronic check           99.65        820.5
# 6               Yes    Credit card (automatic)           89.10       1949.4
# 7                No               Mailed check           29.75        301.9
# 8               Yes           Electronic check          104.80      3046.05
# 9                No  Bank transfer (automatic)           56.15      3487.95
# 10              Yes               Mailed check           49.95       587.45
# 11               No    Credit card (automatic)           18.95        326.8
# 12               No    Credit card (automatic)          100.35       5681.1
# 13              Yes  Bank transfer (automatic)          103.70       5036.3
# 14              Yes           Electronic check          105.50      2686.05
# 15               No    Credit card (automatic)          113.25      7895.15
# 16               No               Mailed check           20.65      1022.95
# 17               No  Bank transfer (automatic)          106.70      7382.25
# 18               No    Credit card (automatic)           55.20       528.35
# 19              Yes           Electronic check           90.05       1862.9
#
#    Churn
# 0     No
# 1     No
# 2    Yes
# 3     No
# 4    Yes
# 5    Yes
# 6     No
# 7     No
# 8    Yes
# 9     No
# 10    No
# 11    No
# 12    No
# 13   Yes
# 14    No
# 15    No
# 16    No
# 17    No
# 18   Yes
# 19    No

# %%
# i found that there is  unimportant column (unnamed 13 ) its a noise column because all its values (nan)
#the customer id is like his name so i cant remove this column
# so i will drop  (unnamed 13 )
# i will change all columns to lowercase

# %%
df['Unnamed: 13'].unique()
# Out:
# array([nan])

# %%
df.drop('Unnamed: 13',axis=1,inplace= True)

# %%
df.columns = df.columns.str.lower()

# %% [markdown]
# ## first step is data under standing
#
# ##### SeniorCitizen: Flags whether the customer is a senior citizen (1) or not (0).
#
# ##### Partner: Shows if the customer has a partner (Yes/No).
#
# ##### Dependents: Shows if the customer has dependents such as children or parents (Yes/No).
#
# ##### MultipleLines: Indicates whether the customer has multiple phone lines or not.
#
# ##### InternetService: Type of internet service the customer subscribes to (DSL/Fiber optic/No).
#
# ##### OnlineSecurity: Indicates if the customer has an additional online security service.
#
# ##### OnlineBackup: Indicates if the customer uses an online backup service.
#
# ##### DeviceProtection: Indicates if the customer has device/equipment protection service.
#
# ##### TechSupport: Indicates if the customer has subscribed to extra technical support.
#
# ##### StreamingTV: Indicates if the customer has a streaming TV service from the provider.
#
# ##### StreamingMovies: Indicates if the customer has a streaming movies service.
#
# ##### Unnamed: 13: Empty/unused column likely created accidentally .
#
# ##### tenure: Number of months the customer has stayed with the company.
#
# ##### PhoneService: Indicates whether the customer has a phone service.
#
# ##### Contract: Type of contract the customer has (month-to-month, one year, two year).
#
# ##### PaperlessBilling: Indicates whether the customer receives electronic (paperless) bills.
#
# ##### PaymentMethod: Method used by the customer to pay their bill (e.g. electronic check, bank transfer).
#
# ##### MonthlyCharges: Current monthly amount charged to the customer.
#
# ##### TotalCharges: Total amount billed to the customer over their entire tenure.
#
#  ##### Churn: Indicates whether the customer has left (churned) or is still active.

# %% [markdown]
# # data exploration

# %%
# i found that the total charges must be float and i have to convert the col of seniorcitizen to be object so i can check the summary statistics
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7042 entries, 0 to 7041
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerid        7042 non-null   object
#  1   gender            7042 non-null   object
#  2   seniorcitizen     7042 non-null   int64
#  3   partner           7042 non-null   object
#  4   dependents        7042 non-null   object
#  5   multiplelines     7042 non-null   object
#  6   internetservice   7042 non-null   object
#  7   onlinesecurity    7042 non-null   object
#  8   onlinebackup      7042 non-null   object
#  9   deviceprotection  7042 non-null   object
#  10  techsupport       7042 non-null   object
#  11  streamingtv       7042 non-null   object
#  12  streamingmovies   7042 non-null   object
#  13  tenure            7042 non-null   int64
#  14  phoneservice      7042 non-null   object
#  15  contract          7042 non-null   object
#  16  paperlessbilling  7042 non-null   object
#  17  paymentmethod     7042 non-null   object
#  18  monthlycharges    7042 non-null   float64
#  19  totalcharges      7042 non-null   object
#  20  churn             7042 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.1+ MB

# %%
# this function to fix the data type of monthly charges
def convert_float(x):
    if x == ' ':
        return 0
    else:
        return float(x)

# %%
df['totalcharges'] = df['totalcharges'].apply(convert_float)

# %%
#to check first if there is any nans
df['seniorcitizen'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
def convert_object(x):
    if x == 0:
        return 'old'
    elif x == 1:
        return 'youth'
    else:
        return 'unkmown'

# %%
df['seniorcitizen']=df['seniorcitizen'].apply(convert_object)

# %%
# summary statistics check for numirical
df.describe(include='number')
# Out:
#             tenure  monthlycharges  totalcharges
# count  7042.000000     7042.000000   7042.000000
# mean     32.366373       64.755886   2279.086083
# std      24.557955       30.088238   2266.302524
# min       0.000000       18.250000      0.000000
# 25%       9.000000       35.500000    398.550000
# 50%      29.000000       70.350000   1394.075000
# 75%      55.000000       89.850000   3783.600000
# max      72.000000      118.750000   8684.800000

# %%
#summary statistics  for categorical
df.describe(include='object')
# Out:
#         customerid gender seniorcitizen partner dependents multiplelines  \
# count         7042   7042          7042    7042       7042          7042
# unique        7042      2             2       2          2             3
# top     7590-VHVEG   Male           old      No         No            No
# freq             1   3554          5900    3640       4932          3389
#
#        internetservice onlinesecurity onlinebackup deviceprotection  \
# count             7042           7042         7042             7042
# unique               3              3            3                3
# top        Fiber optic             No           No               No
# freq              3095           3498         3087             3095
#
#        techsupport streamingtv streamingmovies phoneservice        contract  \
# count         7042        7042            7042         7042            7042
# unique           3           3               3            2               3
# top             No          No              No          Yes  Month-to-month
# freq          3473        2810            2785         6360            3875
#
#        paperlessbilling     paymentmethod churn
# count              7042              7042  7042
# unique                2                 4     2
# top                 Yes  Electronic check    No
# freq               4170              2365  5173

# %%
#check the duplicates
df.duplicated().sum()
# Out:
# 0

# %%
# there is no missing values
df.isna().sum()
# Out:
# customerid          0
# gender              0
# seniorcitizen       0
# partner             0
# dependents          0
# multiplelines       0
# internetservice     0
# onlinesecurity      0
# onlinebackup        0
# deviceprotection    0
# techsupport         0
# streamingtv         0
# streamingmovies     0
# tenure              0
# phoneservice        0
# contract            0
# paperlessbilling    0
# paymentmethod       0
# monthlycharges      0
# totalcharges        0
# churn               0
# dtype: int64

# %% [markdown]
# # data cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7042 entries, 0 to 7041
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerid        7042 non-null   object
#  1   gender            7042 non-null   object
#  2   seniorcitizen     7042 non-null   object
#  3   partner           7042 non-null   object
#  4   dependents        7042 non-null   object
#  5   multiplelines     7042 non-null   object
#  6   internetservice   7042 non-null   object
#  7   onlinesecurity    7042 non-null   object
#  8   onlinebackup      7042 non-null   object
#  9   deviceprotection  7042 non-null   object
#  10  techsupport       7042 non-null   object
#  11  streamingtv       7042 non-null   object
#  12  streamingmovies   7042 non-null   object
#  13  tenure            7042 non-null   int64
#  14  phoneservice      7042 non-null   object
#  15  contract          7042 non-null   object
#  16  paperlessbilling  7042 non-null   object
#  17  paymentmethod     7042 non-null   object
#  18  monthlycharges    7042 non-null   float64
#  19  totalcharges      7042 non-null   float64
#  20  churn             7042 non-null   object
# dtypes: float64(2), int64(1), object(18)
# memory usage: 1.1+ MB

# %%
#i dont need customer id so i will remove
df.drop('customerid',axis=1,inplace=True)

# %%
#in depth checking for categorical cols
cat_col = df.select_dtypes(include='object').columns

# %%
for col in cat_col:
    print(col)
    print(df[col].nunique())
    print(df[col].unique())
# Out:
# gender
# 2
# ['Female' 'Male']
# seniorcitizen
# 2
# ['old' 'youth']
# partner
# 2
# ['Yes' 'No']
# dependents
# 2
# ['No' 'Yes']
# multiplelines
# 3
# ['No phone service' 'No' 'Yes']
# internetservice
# 3
# ['DSL' 'Fiber optic' 'No']
# onlinesecurity
# 3
# ['No' 'Yes' 'No internet service']
# onlinebackup
# 3
# ['Yes' 'No' 'No internet service']
# deviceprotection
# 3
# ['No' 'Yes' 'No internet service']
# techsupport
# 3
# ['No' 'Yes' 'No internet service']
# streamingtv
# 3
# ['No' 'Yes' 'No internet service']
# streamingmovies
# 3
# ['No' 'Yes' 'No internet service']
# phoneservice
# 2
# ['No' 'Yes']
# contract
# 3
# ['Month-to-month' 'One year' 'Two year']
# paperlessbilling
# 2
# ['Yes' 'No']
# paymentmethod
# 4
# ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# churn
# 2
# ['No' 'Yes']

# %%
# after i checked deeply i found that the col of multiple lines i could deal with the people with no phone service the are same 
#like they dont have so i will convert them to no multiple lines
# &
#(multiple lines - online security - online backup -device protection - tech support - stream tv - streaming movies )
# theese col there is some no internet service values and that mean they dont have internet service so they are not subscriping the services
# so i WILL cahnge them to be no

# %%
#this fucnc for the multiplelines col
def covert_unknown1(x):
    if x == 'No phone service':
        return 'unknown'
    else:
        return x

# %%
df['multiplelines']= df['multiplelines'].apply(covert_unknown1)

# %%
#this fucnc for the the other 6 col
def covert_unknown2(x):
    if x == 'No internet service':
        return 'No'
    else:
        return x

# %%
columnn = df[['onlinesecurity', 'onlinebackup','deviceprotection','techsupport','streamingtv','streamingmovies']].columns

# %%
# to apply to the other 6 colmuns
for c in columnn:
    df[c] = df[c].apply(covert_unknown2)

# %%
#now i will make a indepth checking for the num cols
df
# Out:
#       gender seniorcitizen partner dependents multiplelines internetservice  \
# 0     Female           old     Yes         No       unknown             DSL
# 1       Male           old      No         No            No             DSL
# 2       Male           old      No         No            No             DSL
# 3       Male           old      No         No       unknown             DSL
# 4     Female           old      No         No            No     Fiber optic
# ...      ...           ...     ...        ...           ...             ...
# 7037  Female           old      No         No            No              No
# 7038    Male           old     Yes        Yes           Yes             DSL
# 7039  Female           old     Yes        Yes           Yes     Fiber optic
# 7040  Female           old     Yes        Yes       unknown             DSL
# 7041    Male         youth     Yes         No           Yes     Fiber optic
#
#      onlinesecurity onlinebackup deviceprotection techsupport streamingtv  \
# 0                No          Yes               No          No          No
# 1               Yes           No              Yes          No          No
# 2               Yes          Yes               No          No          No
# 3               Yes           No              Yes         Yes          No
# 4                No           No               No          No          No
# ...             ...          ...              ...         ...         ...
# 7037             No           No               No          No          No
# 7038            Yes           No              Yes         Yes         Yes
# 7039             No          Yes              Yes          No         Yes
# 7040            Yes           No               No          No          No
# 7041             No           No               No          No          No
#
#      streamingmovies  tenure phoneservice        contract paperlessbilling  \
# 0                 No       1           No  Month-to-month              Yes
# 1                 No      34          Yes        One year               No
# 2                 No       2          Yes  Month-to-month              Yes
# 3                 No      45           No        One year               No
# 4                 No       2          Yes  Month-to-month              Yes
# ...              ...     ...          ...             ...              ...
# 7037              No      72          Yes        Two year              Yes
# 7038             Yes      24          Yes        One year              Yes
# 7039             Yes      72          Yes        One year              Yes
# 7040              No      11           No  Month-to-month              Yes
# 7041              No       4          Yes  Month-to-month              Yes
#
#                   paymentmethod  monthlycharges  totalcharges churn
# 0              Electronic check           29.85         29.85    No
# 1                  Mailed check           56.95       1889.50    No
# 2                  Mailed check           53.85        108.15   Yes
# 3     Bank transfer (automatic)           42.30       1840.75    No
# 4              Electronic check           70.70        151.65   Yes
# ...                         ...             ...           ...   ...
# 7037  Bank transfer (automatic)           21.15       1419.40    No
# 7038               Mailed check           84.80       1990.50    No
# 7039    Credit card (automatic)          103.20       7362.90    No
# 7040           Electronic check           29.60        346.45    No
# 7041               Mailed check           74.40        306.60   Yes
#
# [7042 rows x 20 columns]

# %%
num_columns = df.select_dtypes(include='number').columns

# %%
for num_c in num_columns:
    px.histogram(data_frame=df[num_c],x=num_c,title=num_c).show()

# %%
df[df['onlinesecurity'] == 'unknowm']['churn'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %% [markdown]
# # feature engneering

# %%
# firstly i wil extract a col from tenure a column that seperate the clients to categories of of terms so i can measure the customer loyality
df
# Out:
#       gender seniorcitizen partner dependents multiplelines internetservice  \
# 0     Female           old     Yes         No       unknown             DSL
# 1       Male           old      No         No            No             DSL
# 2       Male           old      No         No            No             DSL
# 3       Male           old      No         No       unknown             DSL
# 4     Female           old      No         No            No     Fiber optic
# ...      ...           ...     ...        ...           ...             ...
# 7037  Female           old      No         No            No              No
# 7038    Male           old     Yes        Yes           Yes             DSL
# 7039  Female           old     Yes        Yes           Yes     Fiber optic
# 7040  Female           old     Yes        Yes       unknown             DSL
# 7041    Male         youth     Yes         No           Yes     Fiber optic
#
#      onlinesecurity onlinebackup deviceprotection techsupport streamingtv  \
# 0                No          Yes               No          No          No
# 1               Yes           No              Yes          No          No
# 2               Yes          Yes               No          No          No
# 3               Yes           No              Yes         Yes          No
# 4                No           No               No          No          No
# ...             ...          ...              ...         ...         ...
# 7037             No           No               No          No          No
# 7038            Yes           No              Yes         Yes         Yes
# 7039             No          Yes              Yes          No         Yes
# 7040            Yes           No               No          No          No
# 7041             No           No               No          No          No
#
#      streamingmovies  tenure phoneservice        contract paperlessbilling  \
# 0                 No       1           No  Month-to-month              Yes
# 1                 No      34          Yes        One year               No
# 2                 No       2          Yes  Month-to-month              Yes
# 3                 No      45           No        One year               No
# 4                 No       2          Yes  Month-to-month              Yes
# ...              ...     ...          ...             ...              ...
# 7037              No      72          Yes        Two year              Yes
# 7038             Yes      24          Yes        One year              Yes
# 7039             Yes      72          Yes        One year              Yes
# 7040              No      11           No  Month-to-month              Yes
# 7041              No       4          Yes  Month-to-month              Yes
#
#                   paymentmethod  monthlycharges  totalcharges churn
# 0              Electronic check           29.85         29.85    No
# 1                  Mailed check           56.95       1889.50    No
# 2                  Mailed check           53.85        108.15   Yes
# 3     Bank transfer (automatic)           42.30       1840.75    No
# 4              Electronic check           70.70        151.65   Yes
# ...                         ...             ...           ...   ...
# 7037  Bank transfer (automatic)           21.15       1419.40    No
# 7038               Mailed check           84.80       1990.50    No
# 7039    Credit card (automatic)          103.20       7362.90    No
# 7040           Electronic check           29.60        346.45    No
# 7041               Mailed check           74.40        306.60   Yes
#
# [7042 rows x 20 columns]

# %%
def cat_tenure(x):
    if x < 12:
        return 'New'
    elif 12 <= x < 24:
        return 'Somewhat Loyal'
    elif 24 <= x <= 48:
        return 'Loyal'
    else:
        return 'Very Loyal'

# %%
df['cust-loyality'] = df['tenure'].apply(cat_tenure)

# %%
#secondly i will create a col to present the family from partner and dependents col

# %%
def family_size(x):
    if x['partner'] == 'No' and x['dependents'] == 'No':
        return 'Single'
    elif x['partner'] == 'Yes' and x['dependents'] == 'Yes':
        return 'Married With Dependents '
    elif x['partner'] == 'No' and x['dependents'] == 'Yes':
        return 'Singe With Dependents'
    elif x['partner'] == 'Yes' and x['dependents'] == 'No':
        return 'Married'

# %%
df['family_member'] = df.apply(family_size,axis=1)

# %%
df.head(20)
# Out:
#     gender seniorcitizen partner dependents multiplelines internetservice  \
# 0   Female           old     Yes         No       unknown             DSL
# 1     Male           old      No         No            No             DSL
# 2     Male           old      No         No            No             DSL
# 3     Male           old      No         No       unknown             DSL
# 4   Female           old      No         No            No     Fiber optic
# 5   Female           old      No         No           Yes     Fiber optic
# 6     Male           old      No        Yes           Yes     Fiber optic
# 7   Female           old      No         No       unknown             DSL
# 8   Female           old     Yes         No           Yes     Fiber optic
# 9     Male           old      No        Yes            No             DSL
# 10    Male           old     Yes        Yes            No             DSL
# 11    Male           old      No         No            No              No
# 12    Male           old     Yes         No           Yes     Fiber optic
# 13    Male           old      No         No           Yes     Fiber optic
# 14    Male           old      No         No            No     Fiber optic
# 15  Female           old     Yes        Yes           Yes     Fiber optic
# 16  Female           old      No         No            No              No
# 17    Male           old      No        Yes           Yes     Fiber optic
# 18  Female           old     Yes        Yes            No             DSL
# 19  Female           old      No         No            No     Fiber optic
#
#    onlinesecurity onlinebackup deviceprotection techsupport streamingtv  \
# 0              No          Yes               No          No          No
# 1             Yes           No              Yes          No          No
# 2             Yes          Yes               No          No          No
# 3             Yes           No              Yes         Yes          No
# 4              No           No               No          No          No
# 5              No           No              Yes          No         Yes
# 6              No          Yes               No          No         Yes
# 7             Yes           No               No          No          No
# 8              No           No              Yes         Yes         Yes
# 9             Yes          Yes               No          No          No
# 10            Yes           No               No          No          No
# 11             No           No               No          No          No
# 12             No           No              Yes          No         Yes
# 13             No          Yes              Yes          No         Yes
# 14            Yes           No              Yes         Yes         Yes
# 15            Yes          Yes              Yes         Yes         Yes
# 16             No           No               No          No          No
# 17            Yes           No              Yes          No         Yes
# 18             No           No              Yes         Yes          No
# 19             No          Yes              Yes          No          No
#
#    streamingmovies  tenure phoneservice        contract paperlessbilling  \
# 0               No       1           No  Month-to-month              Yes
# 1               No      34          Yes        One year               No
# 2               No       2          Yes  Month-to-month              Yes
# 3               No      45           No        One year               No
# 4               No       2          Yes  Month-to-month              Yes
# 5              Yes       8          Yes  Month-to-month              Yes
# 6               No      22          Yes  Month-to-month              Yes
# 7               No      10           No  Month-to-month               No
# 8              Yes      28          Yes  Month-to-month              Yes
# 9               No      62          Yes        One year               No
# 10              No      13          Yes  Month-to-month              Yes
# 11              No      16          Yes        Two year               No
# 12             Yes      58          Yes        One year               No
# 13             Yes      49          Yes  Month-to-month              Yes
# 14             Yes      25          Yes  Month-to-month              Yes
# 15             Yes      69          Yes        Two year               No
# 16              No      52          Yes        One year               No
# 17             Yes      71          Yes        Two year               No
# 18              No      10          Yes  Month-to-month               No
# 19             Yes      21          Yes  Month-to-month              Yes
#
#                 paymentmethod  monthlycharges  totalcharges churn  \
# 0            Electronic check           29.85         29.85    No
# 1                Mailed check           56.95       1889.50    No
# 2                Mailed check           53.85        108.15   Yes
# 3   Bank transfer (automatic)           42.30       1840.75    No
# 4            Electronic check           70.70        151.65   Yes
# 5            Electronic check           99.65        820.50   Yes
# 6     Credit card (automatic)           89.10       1949.40    No
# 7                Mailed check           29.75        301.90    No
# 8            Electronic check          104.80       3046.05   Yes
# 9   Bank transfer (automatic)           56.15       3487.95    No
# 10               Mailed check           49.95        587.45    No
# 11    Credit card (automatic)           18.95        326.80    No
# 12    Credit card (automatic)          100.35       5681.10    No
# 13  Bank transfer (automatic)          103.70       5036.30   Yes
# 14           Electronic check          105.50       2686.05    No
# 15    Credit card (automatic)          113.25       7895.15    No
# 16               Mailed check           20.65       1022.95    No
# 17  Bank transfer (automatic)          106.70       7382.25    No
# 18    Credit card (automatic)           55.20        528.35   Yes
# 19           Electronic check           90.05       1862.90    No
#
#      cust-loyality             family_member
# 0              New                   Married
# 1            Loyal                    Single
# 2              New                    Single
# 3            Loyal                    Single
# 4              New                    Single
# 5              New                    Single
# 6   Somewhat Loyal     Singe With Dependents
# 7              New                    Single
# 8            Loyal                   Married
# 9       Very Loyal     Singe With Dependents
# 10  Somewhat Loyal  Married With Dependents
# 11  Somewhat Loyal                    Single
# 12      Very Loyal                   Married
# 13      Very Loyal                    Single
# 14           Loyal                    Single
# 15      Very Loyal  Married With Dependents
# 16      Very Loyal                    Single
# 17      Very Loyal     Singe With Dependents
# 18             New  Married With Dependents
# 19  Somewhat Loyal                    Single

# %%
# i will create a new col that will represent the the subscriptions summation 
# that will help me to kmow the customer subscriptions

# %%
def subscription_count(x):
    if x['onlinesecurity'] == 'unknown':
        return 0
    
    cols = ['onlinesecurity', 'onlinebackup', 'deviceprotection',
            'techsupport', 'streamingtv', 'streamingmovies']
    
    count = 0
    for col in cols:
        if x[col] == 'Yes':
            count += 1
    
    if count == 0:
        return 0
    
    return count

df['subscription_count'] = df.apply(subscription_count, axis=1)

# %%
df['subscription_count'].isna().mean() * 100
# Out:
# 0.0

# %% [markdown]
# # machine learning

# %%
df
# Out:
#       gender seniorcitizen partner dependents multiplelines internetservice  \
# 0     Female           old     Yes         No       unknown             DSL
# 1       Male           old      No         No            No             DSL
# 2       Male           old      No         No            No             DSL
# 3       Male           old      No         No       unknown             DSL
# 4     Female           old      No         No            No     Fiber optic
# ...      ...           ...     ...        ...           ...             ...
# 7037  Female           old      No         No            No              No
# 7038    Male           old     Yes        Yes           Yes             DSL
# 7039  Female           old     Yes        Yes           Yes     Fiber optic
# 7040  Female           old     Yes        Yes       unknown             DSL
# 7041    Male         youth     Yes         No           Yes     Fiber optic
#
#      onlinesecurity onlinebackup deviceprotection techsupport streamingtv  \
# 0                No          Yes               No          No          No
# 1               Yes           No              Yes          No          No
# 2               Yes          Yes               No          No          No
# 3               Yes           No              Yes         Yes          No
# 4                No           No               No          No          No
# ...             ...          ...              ...         ...         ...
# 7037             No           No               No          No          No
# 7038            Yes           No              Yes         Yes         Yes
# 7039             No          Yes              Yes          No         Yes
# 7040            Yes           No               No          No          No
# 7041             No           No               No          No          No
#
#      streamingmovies  tenure phoneservice        contract paperlessbilling  \
# 0                 No       1           No  Month-to-month              Yes
# 1                 No      34          Yes        One year               No
# 2                 No       2          Yes  Month-to-month              Yes
# 3                 No      45           No        One year               No
# 4                 No       2          Yes  Month-to-month              Yes
# ...              ...     ...          ...             ...              ...
# 7037              No      72          Yes        Two year              Yes
# 7038             Yes      24          Yes        One year              Yes
# 7039             Yes      72          Yes        One year              Yes
# 7040              No      11           No  Month-to-month              Yes
# 7041              No       4          Yes  Month-to-month              Yes
#
#                   paymentmethod  monthlycharges  totalcharges churn  \
# 0              Electronic check           29.85         29.85    No
# 1                  Mailed check           56.95       1889.50    No
# 2                  Mailed check           53.85        108.15   Yes
# 3     Bank transfer (automatic)           42.30       1840.75    No
# 4              Electronic check           70.70        151.65   Yes
# ...                         ...             ...           ...   ...
# 7037  Bank transfer (automatic)           21.15       1419.40    No
# 7038               Mailed check           84.80       1990.50    No
# 7039    Credit card (automatic)          103.20       7362.90    No
# 7040           Electronic check           29.60        346.45    No
# 7041               Mailed check           74.40        306.60   Yes
#
#      cust-loyality             family_member  subscription_count
# 0              New                   Married                   1
# 1            Loyal                    Single                   2
# 2              New                    Single                   2
# 3            Loyal                    Single                   3
# 4              New                    Single                   0
# ...            ...                       ...                 ...
# 7037    Very Loyal                    Single                   0
# 7038         Loyal  Married With Dependents                    5
# 7039    Very Loyal  Married With Dependents                    4
# 7040           New  Married With Dependents                    1
# 7041           New                   Married                   0
#
# [7042 rows x 23 columns]

# %%
# firstly i have to drop the unnecessary columns before i start ml 
# i found that the family member column gives me the same data of partner and dependents so i will drop both
df = df.drop(['partner','dependents'],axis=1)

# %%
#second i will split the data into train and test
x = df.drop('churn', axis=1)
y = df['churn']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size= 0.2, random_state= 42)

# %%
# second o found that the data have no missing values so will not impute for numerical
df.isna().sum()
# Out:
# gender                0
# seniorcitizen         0
# multiplelines         0
# internetservice       0
# onlinesecurity        0
# onlinebackup          0
# deviceprotection      0
# techsupport           0
# streamingtv           0
# streamingmovies       0
# tenure                0
# phoneservice          0
# contract              0
# paperlessbilling      0
# paymentmethod         0
# monthlycharges        0
# totalcharges          0
# churn                 0
# cust-loyality         0
# family_member         0
# subscription_count    0
# dtype: int64

# %% [markdown]
# # handeling numerical

# %%
#  found that the data have no missing values so will not impute for numerical
# i will scale with robust scaler because there is a lot of outliers in the data 
# first i wil take the num cols in var
num_columns = x_train.select_dtypes(include=['number','float']).columns

# %%
num_columns
# Out:
# Index(['tenure', 'monthlycharges', 'totalcharges', 'subscription_count'], dtype='object')

# %%
# i will do feature scalling using Robust scaller 
from sklearn.preprocessing import RobustScaler

robust_scaler = RobustScaler()

x_train[num_columns] = robust_scaler.fit_transform(x_train[num_columns])
x_test[num_columns] = robust_scaler.transform(x_test[num_columns])

# %% [markdown]
# # handeling categorical

# %%
# firstly i have to divide the categorical columns into nominal columns and ordinal columns
# the ordinal columns is (seniorcitizen	,contract,cust-loyality)
# the nominal columns is (gender,multiplelines,
# internetservice,onlinesecurity,onlinebackup,deviceprotection,
# techsupport,streamingtv,streamingmovies,phoneservice,paperlessbilling,
# paymentmethod,family_member)

# %%
# firstly i will handle ordinal coloumns with ordinal encoder

# %%
# ordinal encoder for seniorcitizen
cat_columns = x_train.select_dtypes(include=['object']).columns
from sklearn.preprocessing import OrdinalEncoder

ord_encoder = OrdinalEncoder(categories= [['youth','old']])

x_train[['seniorcitizen']] = ord_encoder.fit_transform(x_train[['seniorcitizen']])
x_test[['seniorcitizen']] = ord_encoder.transform(x_test[['seniorcitizen']])

# %%
# ordinal encoder for contract
from sklearn.preprocessing import OrdinalEncoder

ord_encoder = OrdinalEncoder(categories= [['Month-to-month','One year','Two year']])

x_train[['contract']] = ord_encoder.fit_transform(x_train[['contract']])
x_test[['contract']] = ord_encoder.transform(x_test[['contract']])

# %%
# ordinal encoder for cust-loyality
from sklearn.preprocessing import OrdinalEncoder

ord_encoder = OrdinalEncoder(categories= [['New','Somewhat Loyal','Loyal','Very Loyal']])

x_train[['cust-loyality']] = ord_encoder.fit_transform(x_train[['cust-loyality']])
x_test[['cust-loyality']] = ord_encoder.transform(x_test[['cust-loyality']])

# %%
# firstly we will look into the count of unique values of the nominal cols to Decide  i will use one hot encoder or binary 
nominal_cols = x_train.select_dtypes(include='object').columns
nominal_cols
# Out:
# Index(['gender', 'multiplelines', 'internetservice', 'onlinesecurity',
#        'onlinebackup', 'deviceprotection', 'techsupport', 'streamingtv',
#        'streamingmovies', 'phoneservice', 'paperlessbilling', 'paymentmethod',
#        'family_member'],
#       dtype='object')

# %%
# i will use one hot encoder for all nominal cols because they all have less than 7 unique values
for col in nominal_cols:
    
    print(col)
    print(x_train[col].nunique())
    print('-' * 50)
# Out:
# gender
# 2
# --------------------------------------------------
# multiplelines
# 3
# --------------------------------------------------
# internetservice
# 3
# --------------------------------------------------
# onlinesecurity
# 2
# --------------------------------------------------
# onlinebackup
# 2
# --------------------------------------------------
# deviceprotection
# 2
# --------------------------------------------------
# techsupport
# 2
# --------------------------------------------------
# streamingtv
# 2
# --------------------------------------------------
# streamingmovies
# 2
# --------------------------------------------------
# phoneservice
# 2
# --------------------------------------------------
# paperlessbilling
# 2
# --------------------------------------------------
# paymentmethod
# 4
# --------------------------------------------------
# family_member
# 4
# --------------------------------------------------

# %%
# the cols that i will apply ohe on them
ohe_cols = x_train.select_dtypes(include='object').columns
ohe_cols
# Out:
# Index(['gender', 'multiplelines', 'internetservice', 'onlinesecurity',
#        'onlinebackup', 'deviceprotection', 'techsupport', 'streamingtv',
#        'streamingmovies', 'phoneservice', 'paperlessbilling', 'paymentmethod',
#        'family_member'],
#       dtype='object')

# %%
from sklearn.preprocessing import OneHotEncoder

ohe = OneHotEncoder(drop= 'first', sparse_output= False)

ohe_arr_train = ohe.fit_transform(x_train[ohe_cols])
ohe_arr_test = ohe.transform(x_test[ohe_cols])

# %%
ohe_df_train = pd.DataFrame(ohe_arr_train, columns = ohe.get_feature_names_out())
ohe_df_test = pd.DataFrame(ohe_arr_test, columns = ohe.get_feature_names_out())

# %%
x_train.reset_index(drop= True, inplace= True)
x_test.reset_index(drop= True, inplace= True)

y_train.reset_index(drop= True, inplace= True)
y_test.reset_index(drop= True, inplace= True)

# %%
x_train = pd.concat([x_train, ohe_df_train], axis= 1).drop(columns= ohe_cols, axis= 1)
x_test = pd.concat([x_test, ohe_df_test], axis= 1).drop(columns= ohe_cols, axis= 1)

# %%
# then we have to handle impalnce because my data is classification because the target col is cat
#  first we have to see the count values for the target col

# %%
# so i have impalance because there is a big diffrent in the percentage 
df['churn'].value_counts(normalize=True) * 100
# Out:
# churn
# No     73.459245
# Yes    26.540755
# Name: proportion, dtype: float64

# %%
# i will use smote to handle the impalance
from imblearn.over_sampling import SMOTE

smote = SMOTE()

x_train_smote, y_train_smote = smote.fit_resample(x_train, y_train)
y_train_smote.value_counts()
# Out:
# churn
# No     4137
# Yes    4137
# Name: count, dtype: int64
